# %%
import scipy.io as spio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Problem 1

# %%
mat = spio.loadmat('data/MardiaExamData.mat', squeeze_me=True)
data = mat['EXAMS']

# %%
X = data[:, :2]
Y = data[:, 2:]
print(X.shape)
print(Y.shape)
# Out:
# (88, 2)
# (88, 3)

# %%
def CCA(X, Y, mean_substract=True):
    '''
    :param X, Y : input vectors to analyze CCA, 
    '''
    if mean_substract:
        X = X - np.mean(X, axis=0)[None, :]
        Y = Y - np.mean(Y, axis=0)[None, :]
    Qx, Rx = np.linalg.qr(X)
    Qy, Ry = np.linalg.qr(Y)
    phi, s, psi = np.linalg.svd(Qx.T@Qy)
    return phi, s, psi, Qx, Rx, Qy, Ry

# %%
phi, s, psi, Qx, Rx, Qy, Ry = CCA(X, Y, True)

# %%
a = np.linalg.pinv(Rx)@phi
b = np.linalg.pinv(Ry)@psi
print(a, b)
# Out:
# [[ 0.00276961  0.00682024]
#  [ 0.00551701 -0.00808835]] [[ 0.01052326  0.00788944  0.00872827]
#  [-0.00104472 -0.010537    0.00084258]
#  [ 0.00050926  0.00149612 -0.00845755]]

# %%
b[:, 1]
# Out:
# array([ 0.00788944, -0.010537  ,  0.00149612])

# %%
alpha = X@a
beta = Y@b

# %%
plt.plot(alpha[:, 0], 'r', label='alpha')
plt.plot(beta[:, 0], 'g', label='beta')
plt.legend()
plt.show()

# %%
u = Qx@phi
v = Qy@psi

# %%
u[:, 0].T@v[:,0] / np.linalg.norm(u[:, 0])/ np.linalg.norm(v[:, 0])
# Out:
# 0.65207817867631868

# %%
s
# Out:
# array([ 0.66305211,  0.04094594])

# %% [markdown]
# # Problem 2

# %%
mat = spio.loadmat('data/MNFdata.mat', squeeze_me=True)
X = mat['X']

X = X - np.mean(X, axis=0)

Xs = np.vstack((X[1:, :], X[0, :]))  # shifted X
dX = X - Xs

# %% [markdown]
# #### Quesiton a-i

# %%
Y = np.linalg.inv(dX.T@dX/2)@X.T@X

w, psi = np.linalg.eig(Y)

phi = X@psi

plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(phi[:, i*2+j])
plt.show()

# %% [markdown]
# #### Quesiton a-ii

# %%
import scipy

# %%
C = X.T@X
D = dX.T@dX/2

# %%
w, psi = scipy.linalg.eig(C, D)

# %%
phi = X@psi

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(phi[:, i*2+j])
plt.show()

# %% [markdown]
# #### Quesiton a-iii

# %%
import matlab.engine
eng = matlab.engine.start_matlab()

# %%
u,v,x,c,s = eng.gsvd(matlab.double((dX/np.sqrt(2)).tolist()), matlab.double(X.tolist()), 0,nargout=5)

# %%
psi = np.linalg.inv(np.array(x).T)

# %%
phi = X@psi

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(phi[:, i*2+j])
plt.show()

# %% [markdown]
# ## c

# %%
u, s, vh = np.linalg.svd(X, full_matrices=False)

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(u[:, i*2+j])
plt.show()

# %% [markdown]
# ## d

# %%
B_mnf = phi[:, :2]
B_svd = u[:, :2]

# %%
proj_mnf, proj_svd = B_mnf@B_mnf.T@X, B_svd@B_svd.T@X

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(proj_mnf[:, i*2+j])
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(proj_svd[:, i*2+j])
plt.show()
