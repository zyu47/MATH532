# %%
import scipy.io as spio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Problem 1

# %%
mat = spio.loadmat('data/MardiaExamData.mat', squeeze_me=True)
data = mat['EXAMS']

# %%
X = data[:, :2]
Y = data[:, 2:]
print(X.shape)
print(Y.shape)
# Out:
# (88, 2)
# (88, 3)

# %%
def CCA(X, Y, mean_substract=False):
    '''
    :param X, Y : input vectors to analyze CCA, 
    '''
    if mean_substract:
        X = X - np.mean(X, axis=0)[None, :]
        Y = Y - np.mean(Y, axis=0)[None, :]
    Qx, Rx = np.linalg.qr(X)
    Qy, Ry = np.linalg.qr(Y)
    phi, s, psi = np.linalg.svd(Qx.T@Qy)
    return phi, s, psi, Qx, Rx, Qy, Ry

# %%
phi, s, psi, Qx, Rx, Qy, Ry = CCA(X, Y, True)

# %%
a = np.linalg.pinv(Rx)@phi
b = np.linalg.pinv(Ry)@psi

# %%
alpha = X@a
beta = Y@b

# %%
plt.plot(alpha[:, 0], 'r')
plt.plot(beta[:, 0], 'g')
plt.show()

# %%
u = Qx@phi
v = Qy@psi

# %%
u[:, 0].T@v[:,0] / np.linalg.norm(u[:, 0])/ np.linalg.norm(v[:, 0])
# Out:
# 0.65207817867631868

# %%
s
# Out:
# array([ 0.66305211,  0.04094594])

# %% [markdown]
# # Problem 2

# %%
mat = spio.loadmat('data/MNFdata.mat', squeeze_me=True)
X = mat['X']

# %%
X
# Out:
# array([[-0.05727779, -0.4724022 ,  0.04326368, -0.02277082],
#        [ 0.10418706, -0.04414252,  0.47278789,  0.12367808],
#        [ 0.0469139 , -0.36107492,  0.16836457,  0.08453152],
#        ...,
#        [-0.04341018,  0.17552561,  0.07976148, -0.0625585 ],
#        [ 0.08524765,  0.5063851 ,  0.38723675,  0.05472194],
#        [ 0.08818548,  0.41491893,  0.26748073,  0.06476625]])

# %%
Xs = np.vstack((X[1:, :], X[0, :]))  # shifted X
dX = X - Xs

# %% [markdown]
# #### Quesiton a-i

# %%
Y = np.linalg.inv(dX.T@dX/2)@X.T@X

# %%
w, psi = np.linalg.eig(Y)

# %%
phi = X@psi

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(phi[:, i*2+j])
plt.show()

# %% [markdown]
# #### Quesiton a-ii

# %%
import scipy

# %%
C = X.T@X
D = dX.T@dX/2

# %%
w, psi = scipy.linalg.eig(C, D)

# %%
phi = X@psi

# %%
plt.figure(figsize=(12,8))
for i in range(2):
    for j in range(2):
        plt.subplot(2,2, i*2 + j + 1)
        plt.plot(phi[:, i*2+j])
plt.show()

# %% [markdown]
# #### Quesiton a-ii

# %%
import matlab.engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-7ec811bb5400> in <module>()
# ----> 1 import matlab.engine
#
# ModuleNotFoundError: No module named 'matlab'
