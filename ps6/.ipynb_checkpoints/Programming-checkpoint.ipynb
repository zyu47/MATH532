# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Problem 1

# %%
data = loadmat('./data/FoCOwxSept.mat')

# %%
plt.plot(data['Temp'])

# %%
def get_embedding(X, T=1):
    X = np.array(X)
    res = np.zeros((X.shape[0]-3*T, 3))
    y = np.zeros((X.shape[0]-3*T))
    for i in range(3*T, res.shape[0]+3*T):
        res[i-3*T] = [X[i-T], X[i-2*T], X[i-3*T]]
        y[i-3*T] = X[i]
    return res, y

# %%
def plot_time_delay_embedding(embed_x):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(embed_x[:, 0], embed_x[:, 1], zs=embed_x[:, 2], marker='.')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.view_init(30, 145)
    plt.show()

# %%
plot_time_delay_embedding(get_embedding(data['Temp'], 1)[0])

# %%
# split training, validation and testing
x, y = get_embedding(data['Temp'], 1)
test_x = x[-500:, :].T
test_y = y[-500:].reshape(1, 500)

train_val_split = 9
val_inds = np.random.randint(x.shape[0]-500, size=(x.shape[0]-500)//train_val_split)
train_inds = np.setdiff1d(range(x.shape[0]-500), val_inds)
train_x = x[train_inds, :].T
train_y = y[train_inds].reshape(1, len(train_inds))
val_x = x[val_inds, :].T
val_y = y[val_inds].reshape(1, len(val_inds))
print(test_x.shape, test_y.shape, train_x.shape, train_y.shape, val_x.shape, val_y.shape)
# Out:
# (3, 500) (1, 500) (3, 2763) (1, 2763) (3, 343) (1, 343)

# %% [markdown]
# # Problem 2

# %%
def phi(r, alpha=1, method=0):
    '''
    This defines the radial basis functions
    '''
    phi_collections = [r, r*r*np.log(r), r**3, np.exp(-(r/alpha)**2), np.sqrt(alpha**2 + r**2), 1/np.sqrt(alpha**2 + r**2)]
    
    return phi_collections[method]

def get_centers(X, Nc, method):
    if method=='rand':
        center_inds = np.random.randint(X.shape[1], size=Nc)
        print(center_inds)
        return X[:, center_inds]
    
def get_PHI(X, centers):
    p = X.shape[1]
    Nc = centers.shape[1]
    PHI = np.ones((p, Nc+1))
    for i in range(p):
        for j in range(1, Nc):
            PHI[i][j] = phi(np.linalg.norm(X[:, i] - centers[:, j-1]))
    return PHI

def RBF_train(X, Y, Nc, method):
    '''
    @:Nc: Number of centers
    '''
    X = np.array(X)
    centers = get_centers(X, Nc, method)
    PHI = get_PHI(X, centers)
    u, s, vh = np.linalg.svd(PHI)
    w = vh.T @ np.linalg.pinv(np.diag(s)) @ u.T @ Y
    
    return w, centers

def RBF_test(X, w, centers, Y_true):
    PHI = get_PHI(X, centers)
    y_pred = PHI @ w
    error = np.sum((y_pred - Y_true.reshape(y_pred))**2) / np.sum((y_pred - np.mean(X, axis=0).reshape(y_pred))**2)
    return y_pred, error

# %%
w, centers = RBF_train(train_x, train_y, 10, 'rand')
# Out:
# [ 939 2146  994  250 1679 1552  524  963 1304  559]
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: divide by zero encountered in log
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: invalid value encountered in double_scalars
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-46e18cb41e9e> in <module>()
# ----> 1 w, centers = RBF_train(train_x, train_y, 10, 'rand')
#
# <ipython-input-120-e84e8d177577> in RBF_train(X, Y, Nc, method)
#      30     PHI = get_PHI(X, centers)
#      31     u, s, vh = np.linalg.svd(PHI)
# ---> 32     w = vh.T @ np.linalg.pinv(np.diag(s)) @ u.T @ Y
#      33
#      34     return w, centers
#
# ValueError: shapes (11,11) and (2763,2763) not aligned: 11 (dim 1) != 2763 (dim 0)
