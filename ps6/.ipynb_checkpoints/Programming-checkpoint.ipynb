# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = loadmat('./data/FoCOwxSept.mat')

# %%
plt.plot(x['Temp'])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x['Temp'][:-2].flatten(), x['Temp'][1:-1].flatten(), zs=x['Temp'][2:].flatten())
plt.show()

# %%
x['Temp'][:-2].shape
# Out:
# (3589, 1)
